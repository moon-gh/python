# %% [markdown]
# some_list.remove(x)는
# some_list에서
# 첫 번째로 x의 값을 갖고 있는 원소를 삭제해줌

# %%
fruits = ["딸기", "당근", "파인애플", "수박", "참외", "메론"]

# %%
fruits.remove("파인애플")

# %%
print(fruits)
# Out:
# ['딸기', '당근', '수박', '참외', '메론']
