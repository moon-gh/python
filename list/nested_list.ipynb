# %%
grades = [[62, 75, 77], [78, 81, 86], [85, 91, 89]]

# %%
print(grades[0])
# Out:
# [62, 75, 77]

# %%
print(grades[2])
# Out:
# [85, 91, 89]

# %%
print(grades[0][0])
# Out:
# 62

# %%
print(grades[2][1])
# Out:
# 91

# %%
print( (grades[0][0] + grades[1][0] + grades[2][0]) / 3)
# Out:
# 75.0
