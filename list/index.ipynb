# %% [markdown]
# some_list.index(x)는
# some_list에서 x의 값을 갖고 있는
# 원소의 인덱스를 return해준다.

# %%
members = ["영훈", "윤수", "태호", "혜린"]

# %%
print(members.index("윤수"))
# Out:
# 1

# %%
print(members.index("태호"))
# Out:
# 2
